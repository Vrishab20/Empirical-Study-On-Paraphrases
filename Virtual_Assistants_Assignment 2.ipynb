# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #D1 Train - Test Split

# %%
import pandas as pd

train_df = pd.read_csv("/content/drive/MyDrive/A2-VA/D1/msr_paraphrase_train.txt", delimiter='\t', names=['label', 'id1', 'id2', 'sentence1', 'sentence2'], skiprows=1, on_bad_lines='skip')
test_df = pd.read_csv("/content/drive/MyDrive/A2-VA/D1/msr_paraphrase_test.txt", delimiter='\t', names=['label', 'id1', 'id2', 'sentence1', 'sentence2'], skiprows=1, on_bad_lines='skip')


# Ensure label column is integer
train_df['label'] = train_df['label'].astype(int)
test_df['label'] = test_df['label'].astype(int)
# Convert sentences to strings (to avoid 'float' errors)
train_df['sentence1'] = train_df['sentence1'].astype(str)
train_df['sentence2'] = train_df['sentence2'].astype(str)

test_df['sentence1'] = test_df['sentence1'].astype(str)
test_df['sentence2'] = test_df['sentence2'].astype(str)


# Print dataset sizes
print(f"Training Set Size: {len(train_df)}, Test Set Size: {len(test_df)}")
# Out:
# Training Set Size: 3938, Test Set Size: 1639

# %% [markdown]
# #Load D2

# %%
df_d2 = pd.read_csv('/content/drive/MyDrive/A2-VA/D2/D2.csv')
df_d2
# Out:
#                   intent                     sentence1  \
# 0            Set a Timer   Set a timer for 10 minutes.
# 1            Set a Timer   Set a timer for 10 minutes.
# 2            Set a Timer   Set a timer for 10 minutes.
# 3            Set a Timer   Set a timer for 10 minutes.
# 4            Set a Timer   Set a timer for 10 minutes.
# ...                  ...                           ...
# 2170  Turn on the Lights       Turn on the chandelier.
# 2171  Turn on the Lights       Turn on the chandelier.
# 2172  Turn on the Lights     Activate the smart bulbs.
# 2173  Turn on the Lights     Activate the smart bulbs.
# 2174  Turn on the Lights  Switch on the garden lights.
#
#                                      sentence2  label
# 0                 Start a 10-minute countdown.      1
# 1               Please time 10 minutes for me.      1
# 2                    Create a 10-minute timer.      0
# 3            Begin a countdown for 10 minutes.      0
# 4     Can you activate a timer for 10 minutes?      0
# ...                                        ...    ...
# 2170              Switch on the garden lights.      0
# 2171                Turn on all indoor lights.      1
# 2172              Switch on the garden lights.      0
# 2173                Turn on all indoor lights.      0
# 2174                Turn on all indoor lights.      1
#
# [2175 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
df_d2_train, df_d2_test = train_test_split(df_d2, test_size=0.2, random_state=42)
print(f"Training Set Size: {len(df_d2_train)}, Test Set Size: {len(df_d2_test)}")
# Out:
# Training Set Size: 1740, Test Set Size: 435

# %% [markdown]
# # Baseline Model

# %%
# Baseline classifier (Exact Match)
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
def baseline_classifier(sentence1, sentence2):
    return 1 if sentence1.strip().lower() == sentence2.strip().lower() else 0

# Evaluate Baseline Model
def evaluate_baseline(df):
    predictions = [baseline_classifier(row['sentence1'], row['sentence2']) for _, row in df.iterrows()]
    accuracy = accuracy_score(df['label'], predictions)
    precision, recall, f1, _ = precision_recall_fscore_support(df['label'], predictions, average='binary')
    print(f'Baseline Model - Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1-score: {f1:.4f}')

# %% [markdown]
# ##Test on D1

# %%
evaluate_baseline(test_df)
# Out:
# Baseline Model - Accuracy: 0.3362, Precision: 0.0000, Recall: 0.0000, F1-score: 0.0000
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ##Test on D2

# %%
evaluate_baseline(df_d2_test)
# Out:
# Baseline Model - Accuracy: 0.5241, Precision: 0.0000, Recall: 0.0000, F1-score: 0.0000
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# #Pretrained model-paraphrase-mpnet-base-v2

# %% [markdown]
# ##Test on D1

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from torch.nn.functional import softmax
from sentence_transformers import SentenceTransformer
import numpy as np
from numpy.linalg import norm
from tqdm import tqdm


# Load Pre-trained Transformer Model
def load_transformer_model():
    model_name = "sentence-transformers/paraphrase-mpnet-base-v2"
    model = SentenceTransformer(model_name)
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    return tokenizer, model

def calculate_embeddings(sentence1, sentence2, tokenizer, embedding_model):
  query_embedding = embedding_model.encode([sentence1])
  passage_embeddings = embedding_model.encode([sentence2])
  return query_embedding, passage_embeddings

def transformer_classifier(query_embedding, passage_embeddings, similarity_threshold):
  similarity = (np.dot(query_embedding, passage_embeddings.T)/(norm(query_embedding)*norm(passage_embeddings)))[0][0]
  if similarity > similarity_threshold:
    return 1
  else:
    return 0


# Evaluate Transformer Model
def evaluate_transformer(df, tokenizer, model):
  embedding_pairs = [calculate_embeddings(row['sentence1'], row['sentence2'], tokenizer, model) for _, row in tqdm(df.iterrows(),total=len(df))]
  for threshold in np.arange(0.5, 0.9, 0.05):
    predictions = [transformer_classifier(e1,e2,threshold) for e1,e2 in embedding_pairs]
    accuracy = accuracy_score(df['label'], predictions)
    precision, recall, f1, _ = precision_recall_fscore_support(df['label'], predictions, average='binary')
    print(f'Transformer Model - Threshold: {threshold}, Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1-score: {f1:.4f}')

# Load Model and Run Evaluation
tokenizer, model = load_transformer_model()
evaluate_transformer(test_df, tokenizer, model)
# Out:
# Evaluating Transformer Model on Test Set...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/594 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# 100%|██████████| 1639/1639 [01:05<00:00, 24.97it/s]
# Transformer Model - Threshold: 0.5, Accuracy: 0.6919, Precision: 0.6867, Recall: 0.9853, F1-score: 0.8094
# Transformer Model - Threshold: 0.55, Accuracy: 0.7077, Precision: 0.6997, Recall: 0.9807, F1-score: 0.8167
# Transformer Model - Threshold: 0.6000000000000001, Accuracy: 0.7303, Precision: 0.7197, Recall: 0.9724, F1-score: 0.8272
# Transformer Model - Threshold: 0.6500000000000001, Accuracy: 0.7413, Precision: 0.7378, Recall: 0.9467, F1-score: 0.8293
# Transformer Model - Threshold: 0.7000000000000002, Accuracy: 0.7492, Precision: 0.7570, Recall: 0.9164, F1-score: 0.8291
# Transformer Model - Threshold: 0.7500000000000002, Accuracy: 0.7523, Precision: 0.7851, Recall: 0.8631, F1-score: 0.8222
# Transformer Model - Threshold: 0.8000000000000003, Accuracy: 0.7224, Precision: 0.8100, Recall: 0.7601, F1-score: 0.7843
# Transformer Model - Threshold: 0.8500000000000003, Accuracy: 0.6736, Precision: 0.8469, Recall: 0.6204, F1-score: 0.7162

# %% [markdown]
# ##Test on D2

# %%
evaluate_transformer(df_d2_test, tokenizer, model)
# Out:
# 100%|██████████| 435/435 [00:11<00:00, 38.25it/s]
# Transformer Model - Threshold: 0.5, Accuracy: 0.4897, Precision: 0.4785, Recall: 0.8068, F1-score: 0.6007
# Transformer Model - Threshold: 0.55, Accuracy: 0.4874, Precision: 0.4739, Recall: 0.7005, F1-score: 0.5653
# Transformer Model - Threshold: 0.6000000000000001, Accuracy: 0.4851, Precision: 0.4641, Recall: 0.5314, F1-score: 0.4955
# Transformer Model - Threshold: 0.6500000000000001, Accuracy: 0.4966, Precision: 0.4659, Recall: 0.3961, F1-score: 0.4282
# Transformer Model - Threshold: 0.7000000000000002, Accuracy: 0.5103, Precision: 0.4750, Recall: 0.2754, F1-score: 0.3486
# Transformer Model - Threshold: 0.7500000000000002, Accuracy: 0.5218, Precision: 0.4912, Recall: 0.1353, F1-score: 0.2121
# Transformer Model - Threshold: 0.8000000000000003, Accuracy: 0.5287, Precision: 0.5333, Recall: 0.0773, F1-score: 0.1350
# Transformer Model - Threshold: 0.8500000000000003, Accuracy: 0.5379, Precision: 0.7500, Recall: 0.0435, F1-score: 0.0822

# %% [markdown]
# #Cross Encoder Model

# %% [markdown]
# ## Training function

# %%
from sentence_transformers import CrossEncoder, InputExample
from torch.utils.data import DataLoader
import torch

def train_cross_encoder(training_data, model_path):
  # Load a pre-trained cross-encoder model
  model = CrossEncoder('cross-encoder/stsb-roberta-base')

  # Prepare the data for training
  train_samples = []
  for _, row in training_data.iterrows():
      train_samples.append(InputExample(texts=[row['sentence1'], row['sentence2']], label=row['label']))

  # Create a DataLoader for batching
  train_dataloader = DataLoader(train_samples, shuffle=True, batch_size=32) # Adjust batch_size as needed

  # Train the model
  model.fit(train_dataloader=train_dataloader, epochs=10, show_progress_bar=True) # Adjust epochs as needed

  # Save the trained model
  model.save(model_path)
  return model

# %% [markdown]
# ##Evaluator Function

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from torch.nn.functional import softmax
from sentence_transformers import SentenceTransformer, CrossEncoder, InputExample
from torch.utils.data import DataLoader
import numpy as np
from numpy.linalg import norm
from tqdm import tqdm

def evaluate_saved_cross_encoder(df, model_path):
    # Load the saved cross-encoder model
    model = CrossEncoder(model_path)

    # Make predictions
    predictions = model.predict([(row['sentence1'], row['sentence2']) for _, row in df.iterrows()])
    # Convert probabilities to class labels (0 or 1)
    predicted_labels = [1 if prob >= 0.5 else 0 for prob in predictions] # Assuming a 0.5 threshold

    # Evaluate the model
    accuracy = accuracy_score(df['label'], predicted_labels)
    precision, recall, f1, _ = precision_recall_fscore_support(df['label'], predicted_labels, average='binary')

    print(f"Cross-Encoder Model - Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1-score: {f1:.4f}")

# %% [markdown]
# ##Train on D1

# %%
# Train the cross-encoder model on the D1 training set
model_d1 = train_cross_encoder(train_df, "/content/drive/MyDrive/A2-VA/D1/trained_cross_encoder_model_d1")
# Out:
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/124 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/124 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/124 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/124 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/124 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/124 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/124 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/124 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/124 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/124 [00:00<?, ?it/s]

# %% [markdown]
# ###Test on D1

# %%
evaluate_saved_cross_encoder(test_df, "/content/drive/MyDrive/A2-VA/D1/trained_cross_encoder_model_d1")
# Out:
# Cross-Encoder Model - Accuracy: 0.8700, Precision: 0.8981, Recall: 0.9072, F1-score: 0.9026

# %% [markdown]
# ###Test on D2

# %%
evaluate_saved_cross_encoder(df_d2_test, "/content/drive/MyDrive/A2-VA/D1/trained_cross_encoder_model_d1")
# Out:
# Saved Cross-Encoder Model - Accuracy: 0.5241, Precision: 0.5000, Recall: 0.3720, F1-score: 0.4266

# %% [markdown]
# ##Train on D2

# %%
# Train the cross-encoder model on the D2 training set
model_d2 = train_cross_encoder(df_d2_train, "/content/drive/MyDrive/A2-VA/D2/trained_cross_encoder_model_d2")
# Out:
# Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/55 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/55 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/55 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/55 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/55 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/55 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/55 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/55 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/55 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/55 [00:00<?, ?it/s]

# %% [markdown]
# ###Test on D1

# %%
evaluate_saved_cross_encoder(test_df, "/content/drive/MyDrive/A2-VA/D2/trained_cross_encoder_model_d2")
# Out:
# Saved Cross-Encoder Model - Accuracy: 0.7688, Precision: 0.7597, Recall: 0.9531, F1-score: 0.8455

# %% [markdown]
# ###Test on D2

# %%
evaluate_saved_cross_encoder(df_d2_test, "/content/drive/MyDrive/A2-VA/D2/trained_cross_encoder_model_d2")
# Out:
# Saved Cross-Encoder Model - Accuracy: 0.5172, Precision: 0.4914, Recall: 0.4155, F1-score: 0.4503

# %% [markdown]
# ## Train on D1+D2

# %%
df_d1_d2 = pd.concat([train_df, df_d2_train], ignore_index=True)
model_d1_d2 = train_cross_encoder(df_d1_d2, "/content/drive/MyDrive/A2-VA/D1_D2/trained_cross_encoder_model_d1_d2")
# Out:
# Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/178 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/178 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/178 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/178 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/178 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/178 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/178 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/178 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/178 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/178 [00:00<?, ?it/s]

# %% [markdown]
# ###Test on D1

# %%
evaluate_saved_cross_encoder(test_df, "/content/drive/MyDrive/A2-VA/D1_D2/trained_cross_encoder_model_d1_d2")
# Out:
# Saved Cross-Encoder Model - Accuracy: 0.8737, Precision: 0.9045, Recall: 0.9053, F1-score: 0.9049

# %% [markdown]
# ###Test on D2

# %%
evaluate_saved_cross_encoder(df_d2_test, "/content/drive/MyDrive/A2-VA/D1_D2/trained_cross_encoder_model_d1_d2")
# Out:
# Saved Cross-Encoder Model - Accuracy: 0.5103, Precision: 0.4828, Recall: 0.4058, F1-score: 0.4409

# %% [markdown]
# #Misclassified Examples

# %%
misclassified_indices = [i for i, (pred, true) in enumerate(zip([1 if pred >= 0.5 else 0 for pred in test_predictions_d2], df_d2_test['label'])) if pred != true]

for i in  misclassified_indices:
  print(f"Index: {i}")
  print(f"Sentence 1: {df_d2_test.iloc[i]['sentence1']}")
  print(f"Sentence 2: {df_d2_test.iloc[i]['sentence2']}")
  print(f"Predicted Label: {[1 if test_predictions_d2[i] >= 0.5 else 0][0]}")
  print(f"True Label: {df_d2_test.iloc[i]['label']}")
  print("---")
# Out:
# Index: 1
# Sentence 1: Let John know I’m on my way.
# Sentence 2: Text John and ask if he's free.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 5
# Sentence 1: Tell John I’ll call him later.
# Sentence 2: Tell John to call me when he's free.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 11
# Sentence 1: Create a 10-minute timer.
# Sentence 2: Put on a countdown for 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 12
# Sentence 1: Text John and say hello.
# Sentence 2: Tell John I’ll text him later.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 13
# Sentence 1: Can you brighten the room?
# Sentence 2: Turn on the chandelier.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 15
# Sentence 1: Let John know I’m on my way.
# Sentence 2: Write a text message to John.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 17
# Sentence 1: Remind me in 10 minutes.
# Sentence 2: Set an alarm for 10 minutes from now.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 18
# Sentence 1: Play upbeat tracks.
# Sentence 2: Turn on some tunes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 20
# Sentence 1: Turn up the lights.
# Sentence 2: Switch on the LED lights.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 21
# Sentence 1: Can you message John?
# Sentence 2: Inform John that I’ve arrived.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 26
# Sentence 1: Turn on all the lights.
# Sentence 2: Turn on the bedroom lights.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 28
# Sentence 1: Begin a countdown for 10 minutes.
# Sentence 2: Start a stopwatch for 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 29
# Sentence 1: Tell John I’ll call him later.
# Sentence 2: Message John to confirm our plans.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 30
# Sentence 1: Let me know when 10 minutes have passed.
# Sentence 2: Countdown 10 minutes for me.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 33
# Sentence 1: What's the temperature outside?
# Sentence 2: Give me the expected temperature for today.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 37
# Sentence 1: Please time 10 minutes for me.
# Sentence 2: Track time for 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 40
# Sentence 1: Send a reminder message to John.
# Sentence 2: Send John a message asking how he's doing.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 41
# Sentence 1: Let's listen to music.
# Sentence 2: Put on some relaxing sounds.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 48
# Sentence 1: Turn on the radio.
# Sentence 2: Play some rock music.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 51
# Sentence 1: Send John a message asking how he's doing.
# Sentence 2: Let John know I’ll be late.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 52
# Sentence 1: Can you switch on the lights?
# Sentence 2: Enable the lighting in the house.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 54
# Sentence 1: Count down from 10 minutes.
# Sentence 2: Put on a countdown for 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 55
# Sentence 1: Start my favorite playlist.
# Sentence 2: Turn on some tunes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 56
# Sentence 1: Check the forecast for this evening.
# Sentence 2: Give me today's high and low temperatures.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 58
# Sentence 1: Play classical music.
# Sentence 2: I want to hear some music.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 64
# Sentence 1: Start playing jazz music.
# Sentence 2: Put on some relaxing sounds.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 65
# Sentence 1: How's the weather right now?
# Sentence 2: What's the weather like in my area?
# Predicted Label: 1
# True Label: 0
# ---
# Index: 66
# Sentence 1: Remind me in 10 minutes.
# Sentence 2: Help me count down 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 70
# Sentence 1: Is it going to rain today?
# Sentence 2: Is it warm outside?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 72
# Sentence 1: Switch on the LED lights.
# Sentence 2: Turn on all indoor lights.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 74
# Sentence 1: Turn on the radio.
# Sentence 2: Start the music player.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 75
# Sentence 1: Can you message John?
# Sentence 2: Let John know I’m on my way.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 79
# Sentence 1: Can you play my top hits?
# Sentence 2: Turn on some tunes.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 80
# Sentence 1: Send John a message asking how he's doing.
# Sentence 2: Tell John to call me when he's free.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 82
# Sentence 1: Start playing jazz music.
# Sentence 2: Begin my party playlist.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 83
# Sentence 1: Write a message to John.
# Sentence 2: Text John to check in with him.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 84
# Sentence 1: Light up the kitchen area.
# Sentence 2: Switch on the garden lights.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 87
# Sentence 1: Please time 10 minutes for me.
# Sentence 2: Put on a countdown for 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 88
# Sentence 1: Can you brighten the room?
# Sentence 2: Make the space well-lit.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 89
# Sentence 1: Turn on the bedroom lights.
# Sentence 2: Turn on the hallway light.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 91
# Sentence 1: Switch on the ceiling light.
# Sentence 2: Light up the kitchen area.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 93
# Sentence 1: Send a short text to John.
# Sentence 2: Ask John if he received my email.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 94
# Sentence 1: Can you switch on the lights?
# Sentence 2: Turn on the lights now.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 97
# Sentence 1: How cold is it outside?
# Sentence 2: What's the weather going to be like tomorrow?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 99
# Sentence 1: Play something relaxing.
# Sentence 2: Queue my best songs.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 100
# Sentence 1: Please time 10 minutes for me.
# Sentence 2: Start a countdown clock for 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 101
# Sentence 1: Enable the lighting in the house.
# Sentence 2: Can you activate the living room lights?
# Predicted Label: 1
# True Label: 0
# ---
# Index: 102
# Sentence 1: Illuminate the living room.
# Sentence 2: Turn on all the lights.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 103
# Sentence 1: Send John a quick text.
# Sentence 2: Inform John that I’ve arrived.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 104
# Sentence 1: What's the temperature outside?
# Sentence 2: Check the forecast for this evening.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 105
# Sentence 1: Let John know I’m on my way.
# Sentence 2: Tell John that I’m running late.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 106
# Sentence 1: Turn on the bedroom lights.
# Sentence 2: Switch on the LED lights.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 107
# Sentence 1: Message John with my location.
# Sentence 2: Message John and ask about the meeting.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 108
# Sentence 1: Text John for me.
# Sentence 2: Write a text message to John.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 109
# Sentence 1: Start a countdown clock for 10 minutes.
# Sentence 2: Start the timer and stop after 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 113
# Sentence 1: Set a countdown for 10 minutes.
# Sentence 2: Begin a 10-minute alert.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 114
# Sentence 1: Text John to check in with him.
# Sentence 2: Write a message to John and say thanks.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 118
# Sentence 1: Switch on the ceiling light.
# Sentence 2: Switch on the night light.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 120
# Sentence 1: Start a stopwatch for 10 minutes.
# Sentence 2: Put on a countdown for 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 124
# Sentence 1: Send a WhatsApp message to John.
# Sentence 2: Tell John to call me when he's free.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 126
# Sentence 1: Tell me if it's sunny outside.
# Sentence 2: Is it going to be windy today?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 127
# Sentence 1: Start a countdown clock for 10 minutes.
# Sentence 2: Run a stopwatch for 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 130
# Sentence 1: Enable the lights in this room.
# Sentence 2: Increase the brightness in the room.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 131
# Sentence 1: Turn on the radio.
# Sentence 2: Can you start the music?
# Predicted Label: 1
# True Label: 0
# ---
# Index: 132
# Sentence 1: Tell John I’ll be there soon.
# Sentence 2: Message John and ask about the meeting.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 134
# Sentence 1: Ask John if he received my email.
# Sentence 2: Send John a text with my ETA.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 136
# Sentence 1: Send a reminder message to John.
# Sentence 2: Let John know I’ll be late.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 137
# Sentence 1: Send a text to John saying hi.
# Sentence 2: Message John with my location.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 138
# Sentence 1: Power on the lights.
# Sentence 2: Turn on all indoor lights.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 140
# Sentence 1: Turn on some tunes.
# Sentence 2: Start the music player.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 142
# Sentence 1: Give me the weekly weather forecast.
# Sentence 2: How cold is it outside?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 143
# Sentence 1: Can you start a 10-minute stopwatch?
# Sentence 2: Countdown 10 minutes for me.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 145
# Sentence 1: Send a message to John.
# Sentence 2: Send John a quick text.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 147
# Sentence 1: Tell John I’ll call him later.
# Sentence 2: Message John and ask about the meeting.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 150
# Sentence 1: Send a message to John.
# Sentence 2: Let John know I’ll be late.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 151
# Sentence 1: Will it snow today?
# Sentence 2: Give me the expected temperature for today.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 152
# Sentence 1: Start a 10-minute countdown.
# Sentence 2: Keep track of 10 minutes for me.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 153
# Sentence 1: Help me count down 10 minutes.
# Sentence 2: Enable a timer for 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 154
# Sentence 1: Start a countdown clock for 10 minutes.
# Sentence 2: Give me an alert after 10 minutes.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 155
# Sentence 1: Can you switch on the lights?
# Sentence 2: Illuminate the living room.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 156
# Sentence 1: Is it going to rain today?
# Sentence 2: Will it snow today?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 157
# Sentence 1: What's the weather like today?
# Sentence 2: Is it cloudy or clear today?
# Predicted Label: 1
# True Label: 0
# ---
# Index: 160
# Sentence 1: Play some music.
# Sentence 2: Resume my last played track.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 164
# Sentence 1: Check the air quality for me.
# Sentence 2: What's the weather update for this weekend?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 166
# Sentence 1: I need a reminder in 10 minutes.
# Sentence 2: Start a timer exactly for 10 minutes.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 167
# Sentence 1: Put on a countdown for 10 minutes.
# Sentence 2: Let me know when 10 minutes have passed.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 169
# Sentence 1: Switch on the ceiling light.
# Sentence 2: Switch on the LED lights.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 171
# Sentence 1: Illuminate the house.
# Sentence 2: Switch on the garden lights.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 172
# Sentence 1: Begin a 10-minute alert.
# Sentence 2: Start a timer exactly for 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 173
# Sentence 1: Start my favorite playlist.
# Sentence 2: Queue my best songs.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 174
# Sentence 1: Enable the lights in this room.
# Sentence 2: Turn on the chandelier.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 176
# Sentence 1: Remind me in 10 minutes.
# Sentence 2: Start a countdown clock for 10 minutes.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 177
# Sentence 1: I want to hear some music.
# Sentence 2: Turn on Spotify and play songs.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 178
# Sentence 1: Give me an alert after 10 minutes.
# Sentence 2: Run a stopwatch for 10 minutes.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 179
# Sentence 1: Illuminate the living room.
# Sentence 2: Light up the kitchen area.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 184
# Sentence 1: Is it going to rain today?
# Sentence 2: Should I wear sunglasses today?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 189
# Sentence 1: Enable the wall lamps.
# Sentence 2: Turn on the chandelier.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 190
# Sentence 1: Tell John I’ll text him later.
# Sentence 2: Send a short text to John.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 193
# Sentence 1: Begin a countdown for 10 minutes.
# Sentence 2: I want a timer set for 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 197
# Sentence 1: Start a 10-minute countdown.
# Sentence 2: Countdown 10 minutes for me.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 198
# Sentence 1: Make the space well-lit.
# Sentence 2: Activate the smart bulbs.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 200
# Sentence 1: Play my most recent playlist.
# Sentence 2: Play an instrumental song.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 201
# Sentence 1: Help me count down 10 minutes.
# Sentence 2: Let me know when 10 minutes have passed.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 202
# Sentence 1: Can you play my top hits?
# Sentence 2: Shuffle and play my playlist.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 205
# Sentence 1: Tell John I’ll text him later.
# Sentence 2: Ask John if he received my email.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 210
# Sentence 1: Play something relaxing.
# Sentence 2: Play upbeat tracks.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 213
# Sentence 1: Text John for me.
# Sentence 2: Message John and ask about the meeting.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 216
# Sentence 1: Can you play my top hits?
# Sentence 2: Play some rock music.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 218
# Sentence 1: Ask John if he received my email.
# Sentence 2: Send John a message asking how he's doing.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 219
# Sentence 1: Start a 10-minute countdown.
# Sentence 2: Can you start a 10-minute stopwatch?
# Predicted Label: 1
# True Label: 0
# ---
# Index: 220
# Sentence 1: Start my favorite playlist.
# Sentence 2: Put on some relaxing sounds.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 222
# Sentence 1: Power on the lights.
# Sentence 2: Switch on the night light.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 224
# Sentence 1: Start playing jazz music.
# Sentence 2: Play an instrumental song.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 226
# Sentence 1: Tell me today's weather report.
# Sentence 2: Give me the weather forecast.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 227
# Sentence 1: Send a reminder message to John.
# Sentence 2: Tell John to call me when he's free.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 229
# Sentence 1: How cold is it outside?
# Sentence 2: Give me the expected temperature for today.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 230
# Sentence 1: Let's listen to music.
# Sentence 2: Play some rock music.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 231
# Sentence 1: Play my most recent playlist.
# Sentence 2: Play my last listened-to music.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 237
# Sentence 1: Count down from 10 minutes.
# Sentence 2: I want a timer set for 10 minutes.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 238
# Sentence 1: Remind me in 10 minutes.
# Sentence 2: Can you start a 10-minute stopwatch?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 241
# Sentence 1: Turn on all the lights.
# Sentence 2: Illuminate the house.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 244
# Sentence 1: What's the weather like in my area?
# Sentence 2: Give me the expected temperature for today.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 245
# Sentence 1: I want a timer set for 10 minutes.
# Sentence 2: Enable a timer for 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 248
# Sentence 1: Turn on a timer for 10 minutes.
# Sentence 2: Countdown 10 minutes for me.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 250
# Sentence 1: Switch on the ceiling light.
# Sentence 2: Activate the smart bulbs.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 251
# Sentence 1: Light up the kitchen area.
# Sentence 2: Turn on all indoor lights.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 252
# Sentence 1: Put on a song.
# Sentence 2: Turn on Spotify and play songs.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 257
# Sentence 1: Create a 10-minute timer.
# Sentence 2: Track time for 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 259
# Sentence 1: Put on a countdown for 10 minutes.
# Sentence 2: I need a reminder in 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 261
# Sentence 1: Is it going to rain today?
# Sentence 2: Do I need an umbrella today?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 262
# Sentence 1: Write a message to John.
# Sentence 2: Text John and say hello.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 265
# Sentence 1: Begin a countdown for 10 minutes.
# Sentence 2: Track time for 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 268
# Sentence 1: Tell John I’ll call him later.
# Sentence 2: Message John and let him know I’m outside.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 270
# Sentence 1: Please time 10 minutes for me.
# Sentence 2: Can you time me for 10 minutes?
# Predicted Label: 1
# True Label: 0
# ---
# Index: 271
# Sentence 1: How's the weather right now?
# Sentence 2: Tell me if it's stormy outside.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 272
# Sentence 1: Can you light up the space?
# Sentence 2: Light up the kitchen area.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 273
# Sentence 1: What's the weather like today?
# Sentence 2: What's the humidity level today?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 274
# Sentence 1: Can you message John?
# Sentence 2: Ask John if he received my email.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 275
# Sentence 1: Tell me today's weather report.
# Sentence 2: Is it going to be windy today?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 277
# Sentence 1: Turn on the lights now.
# Sentence 2: Switch on the garden lights.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 279
# Sentence 1: Send a reminder message to John.
# Sentence 2: Message John and ask about the meeting.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 280
# Sentence 1: Turn up the lights.
# Sentence 2: Turn on the hallway light.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 281
# Sentence 1: Can you start the music?
# Sentence 2: Queue my best songs.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 284
# Sentence 1: I need a timer for 10 minutes.
# Sentence 2: Can you start a 10-minute stopwatch?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 285
# Sentence 1: Turn on the hallway light.
# Sentence 2: Make the space well-lit.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 286
# Sentence 1: Turn up the lights.
# Sentence 2: Enable the wall lamps.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 287
# Sentence 1: Text John and say hello.
# Sentence 2: Let John know I’ll meet him at 5.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 290
# Sentence 1: Illuminate the living room.
# Sentence 2: Can you light up the space?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 291
# Sentence 1: Start the music player.
# Sentence 2: Resume my last played track.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 293
# Sentence 1: Turn on the lights in the living room.
# Sentence 2: Illuminate the house.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 295
# Sentence 1: Play upbeat tracks.
# Sentence 2: Play some rock music.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 296
# Sentence 1: Can you play my top hits?
# Sentence 2: Put on some background music.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 301
# Sentence 1: Count down from 10 minutes.
# Sentence 2: Begin a 10-minute alert.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 302
# Sentence 1: Show me today's weather conditions.
# Sentence 2: Give me the expected temperature for today.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 304
# Sentence 1: Start my favorite playlist.
# Sentence 2: Turn on my music list.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 306
# Sentence 1: Send John a quick text.
# Sentence 2: Message John and ask about the meeting.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 307
# Sentence 1: Play my last listened-to music.
# Sentence 2: Queue my best songs.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 308
# Sentence 1: Give me the latest weather update.
# Sentence 2: Check the air quality for me.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 310
# Sentence 1: Send a message to John.
# Sentence 2: Send a WhatsApp message to John.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 314
# Sentence 1: Give me the weather forecast.
# Sentence 2: Tell me if it's sunny outside.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 315
# Sentence 1: Message John with my location.
# Sentence 2: Let John know I’ll meet him at 5.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 319
# Sentence 1: Give me an alert after 10 minutes.
# Sentence 2: Keep track of 10 minutes for me.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 320
# Sentence 1: Start my favorite playlist.
# Sentence 2: Start playing jazz music.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 324
# Sentence 1: Write a text message to John.
# Sentence 2: Text John to check in with him.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 326
# Sentence 1: How's the weather right now?
# Sentence 2: Do I need an umbrella today?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 332
# Sentence 1: Play some music.
# Sentence 2: Put on some background music.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 333
# Sentence 1: Turn on the hallway light.
# Sentence 2: Turn on the chandelier.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 335
# Sentence 1: Give me an alert after 10 minutes.
# Sentence 2: Put on a countdown for 10 minutes.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 336
# Sentence 1: Give me the latest weather update.
# Sentence 2: Give me the expected temperature for today.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 340
# Sentence 1: Send a reminder message to John.
# Sentence 2: Write a text message to John.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 343
# Sentence 1: Give me the latest weather update.
# Sentence 2: Is it warm outside?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 345
# Sentence 1: Play my last listened-to music.
# Sentence 2: Shuffle and play my playlist.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 347
# Sentence 1: Please time 10 minutes for me.
# Sentence 2: Begin a 10-minute alert.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 348
# Sentence 1: Tell me today's weather report.
# Sentence 2: Should I wear a jacket today?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 349
# Sentence 1: Send John a message asking how he's doing.
# Sentence 2: Send John a text with my ETA.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 350
# Sentence 1: Text John and ask if he's free.
# Sentence 2: Message John and ask about the meeting.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 353
# Sentence 1: Check the weather for me.
# Sentence 2: How cold is it outside?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 356
# Sentence 1: Turn on the lights in the living room.
# Sentence 2: Turn up the lights.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 358
# Sentence 1: Tell me the chance of rain today.
# Sentence 2: Will it snow today?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 364
# Sentence 1: Tell me today's weather report.
# Sentence 2: What's the humidity level today?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 367
# Sentence 1: Play a song for me.
# Sentence 2: Turn on Spotify and play songs.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 374
# Sentence 1: Light up the kitchen area.
# Sentence 2: Illuminate the house.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 376
# Sentence 1: Send a reminder message to John.
# Sentence 2: Message John and let him know I’m outside.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 379
# Sentence 1: Make the room brighter.
# Sentence 2: Enable the lighting in the house.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 381
# Sentence 1: Track time for 10 minutes.
# Sentence 2: Let me know when 10 minutes have passed.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 385
# Sentence 1: Keep track of 10 minutes for me.
# Sentence 2: Help me count down 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 386
# Sentence 1: Play upbeat tracks.
# Sentence 2: Start playing jazz music.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 387
# Sentence 1: Message John and ask about the meeting.
# Sentence 2: Write a message to John and say thanks.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 389
# Sentence 1: What's the weather going to be like tomorrow?
# Sentence 2: Tell me if it's stormy outside.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 390
# Sentence 1: Turn on the radio.
# Sentence 2: Begin my party playlist.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 391
# Sentence 1: Send a message to John.
# Sentence 2: Text John and say hello.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 392
# Sentence 1: Turn on the hallway light.
# Sentence 2: Light up the kitchen area.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 393
# Sentence 1: What's the weather like in my area?
# Sentence 2: Will it snow today?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 394
# Sentence 1: Start my saved songs.
# Sentence 2: Play classical music.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 398
# Sentence 1: I need a timer for 10 minutes.
# Sentence 2: Remind me in 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 402
# Sentence 1: Can you play my top hits?
# Sentence 2: Shuffle my favorite songs.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 406
# Sentence 1: Set a timer for 10 minutes.
# Sentence 2: Keep track of 10 minutes for me.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 408
# Sentence 1: Put on some background music.
# Sentence 2: Put on some relaxing sounds.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 409
# Sentence 1: Can you play my top hits?
# Sentence 2: Play an instrumental song.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 412
# Sentence 1: Start a stopwatch for 10 minutes.
# Sentence 2: Run a stopwatch for 10 minutes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 413
# Sentence 1: Let me know when 10 minutes have passed.
# Sentence 2: Enable a timer for 10 minutes.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 414
# Sentence 1: Will it snow today?
# Sentence 2: What's the weather update for this weekend?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 416
# Sentence 1: Start a countdown clock for 10 minutes.
# Sentence 2: I need a reminder in 10 minutes.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 418
# Sentence 1: Play my most recent playlist.
# Sentence 2: Can you start the music?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 419
# Sentence 1: Please time 10 minutes for me.
# Sentence 2: Can you activate a timer for 10 minutes?
# Predicted Label: 1
# True Label: 0
# ---
# Index: 420
# Sentence 1: Please time 10 minutes for me.
# Sentence 2: Can you start a 10-minute stopwatch?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 421
# Sentence 1: Let's listen to music.
# Sentence 2: Turn on some tunes.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 422
# Sentence 1: Turn on all the lights.
# Sentence 2: Turn on the chandelier.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 425
# Sentence 1: Tell me if it's sunny outside.
# Sentence 2: Check the air quality for me.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 426
# Sentence 1: Give me the weather forecast.
# Sentence 2: Should I wear sunglasses today?
# Predicted Label: 0
# True Label: 1
# ---
# Index: 429
# Sentence 1: Start a stopwatch for 10 minutes.
# Sentence 2: Remind me in 10 minutes.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 431
# Sentence 1: What's the weather like in my area?
# Sentence 2: Should I wear a jacket today?
# Predicted Label: 0
# True Label: 1
# ---

# %%
model_path_d1 = "/content/drive/MyDrive/A2-VA/D1/trained_cross_encoder_model_d1"
model_d1 = CrossEncoder(model_path_d1)
test_predictions_d1 = model_d1.predict([(row['sentence1'], row['sentence2']) for _, row in test_df.iterrows()])


misclassified_indices_d1 = [i for i, (pred, true) in enumerate(zip([1 if pred >= 0.5 else 0 for pred in test_predictions_d1], test_df['label'])) if pred != true]

for i in  misclassified_indices_d1:
  print(f"Index: {i}")
  print(f"Sentence 1: {test_df.iloc[i]['sentence1']}")
  print(f"Sentence 2: {test_df.iloc[i]['sentence2']}")
  print(f"Predicted Label: {[1 if test_predictions_d1[i] >= 0.5 else 0][0]}")
  print(f"True Label: {test_df.iloc[i]['label']}")
  print("---")
# Out:
# Index: 3
# Sentence 1: A tropical storm rapidly developed in the Gulf of Mexico Sunday and was expected to hit somewhere along the Texas or Louisiana coasts by Monday night.
# Sentence 2: A tropical storm rapidly developed in the Gulf of Mexico on Sunday and could have hurricane-force winds when it hits land somewhere along the Louisiana coast Monday night.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 15
# Sentence 1: Ballmer has been vocal in the past warning that Linux is a threat to Microsoft.
# Sentence 2: In the memo, Ballmer reiterated the open-source threat to Microsoft.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 22
# Sentence 1: Senator Clinton should be ashamed of herself for playing politics with the important issue of homeland security funding, he said.
# Sentence 2: She should be ashamed of herself for playing politics with this important issue, said state budget division spokesman Andrew Rush.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 41
# Sentence 1: Thanks to the euro's rise against the Japanese currency, the dollar was at 117.24 yen, well above the overnight 10-month low of 116 yen.
# Sentence 2: The euro's rise against the yen and speculation of Japanese intervention helped the dollar firm to 117.25 yen , well above a 10-month low of 116 yen hit on Thursday.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 65
# Sentence 1: Agriculture ministers from more than one hundred nations are expected to attend the three-day Ministerial Conference and Expo on Agricultural Science and Technology sponsored by the U.S. Department of Agriculture.
# Sentence 2: U.S. Agriculture Secretary Ann Veneman kicks off the three-day Ministerial Conference and Expo on Agricultural Science and Technology on Monday.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 70
# Sentence 1: Amgen shares gained 93 cents, or 1.45 percent, to $65.05 in afternoon trading on Nasdaq.
# Sentence 2: Shares of Allergan were up 14 cents at $78.40 in late trading on the New York Stock Exchange.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 85
# Sentence 1: WorldCom's accounting problems came to light early last year, and the company filed for bankruptcy in July 2002, citing massive accounting irregularities.
# Sentence 2: WorldCom's financial troubles came to light last year and the company subsequently filed for bankruptcy in July, 2002.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 86
# Sentence 1: They were at Raffles Hospital over the weekend for further evaluation.
# Sentence 2: They underwent more tests over the weekend, and are now warded at Raffles Hospital.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 101
# Sentence 1: The blue-chip Dow Jones industrial average .DJI added 38 points, or 0.42 percent, to 9,165.
# Sentence 2: The Dow Jones Industrial Average [$INDU] ended at session highs, gaining 64.64 points, or 0.7 percent, to 9,191.09.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 113
# Sentence 1: Garner said the self-proclaimed mayor of Baghdad, Mohammed Mohsen al-Zubaidi, was released after two days in coalition custody.
# Sentence 2: Garner said self-proclaimed Baghdad mayor Mohammed Mohsen Zubaidi was released 48 hours after his detention in late April.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 116
# Sentence 1: In a not-too-subtle swipe at Dean, he predicted Americans would not elect a Democrat "who sounds an uncertain trumpet in these dangerous times."
# Sentence 2: They will not elect as president a Democrat who sounds an uncertain trumpet in these dangerous times."
# Predicted Label: 1
# True Label: 0
# ---
# Index: 123
# Sentence 1: It appears from our initial report that this was a textbook landing considering the circumstances, Burke said.
# Sentence 2: Said Mr. Burke: "It was a textbook landing considering the circumstances."
# Predicted Label: 1
# True Label: 0
# ---
# Index: 124
# Sentence 1: By Sunday night, the fires had blackened 277,000 acres, hundreds of miles apart.
# Sentence 2: Major fires had burned 264,000 acres by early last night.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 141
# Sentence 1: Hotly contested legislation that would change the state's takeover law and help a Michigan-based development company fend off a takeover cleared the state Senate on Thursday.
# Sentence 2: Legislation that would change state takeover law and help Bloomfield Hills-based Taubman Centers Inc. fend off a $1-billion takeover won committee approval Tuesday.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 158
# Sentence 1: The BlueCore3-Multimedia includes a 16-bit stereo audio CODEC with dual ADC and DAC for stereo audio.
# Sentence 2: BlueCore3-Multimedia contains an open platform DSP co-processor and also includes a 16-bit stereo audio codec with dual ADC and DAC for stereo audio.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 164
# Sentence 1: While the day's trading was lackluster, the Standard & Poor's 500 index was preparing to close out its best three-month period since the fourth quarter of 1998.
# Sentence 2: The Standard & Poor's 500 stock index ended the quarter up 120 points, a gain of 14 percent, the best performance for that broad market benchmark since 1998.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 165
# Sentence 1: Powell recently changed the story, telling officers that Hoffa's body was buried at his former home, where the search was conducted Wednesday.
# Sentence 2: Powell changed the story earlier this year, telling officers that Hoffa's body was buried at his former home, where the aboveground pool now sits.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 169
# Sentence 1: SCO says the pricing terms for a license will not be announced for weeks.
# Sentence 2: Details on pricing will be announced within a few weeks, McBride said.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 173
# Sentence 1: Both studies are published in the Journal of the American Medical Association.
# Sentence 2: The study appears in the latest issue of the Journal of the American Medical Association.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 178
# Sentence 1: The three men have pleaded not guilty and their lawyers have asked the High Court to dismiss the charges, saying the state has failed to present a solid case.
# Sentence 2: Defense lawyers asked the High Court to dismiss the charges, saying the state has failed to present a solid case.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 179
# Sentence 1: A Florida grand jury investigating pharmaceutical wholesalers indicted 19 people on charges of peddling bogus or diluted medications often prescribed for cancer and AIDS patients, authorities said yesterday.
# Sentence 2: A Florida grand jury indicted 19 people for contaminating and diluting prescription drugs desperately needed by AIDS and cancer patients in a multimillion-dollar scheme, prosecutors said Monday.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 186
# Sentence 1: The main psychologist, Dwight Close, referred questions to an agency spokeswoman, who said she wouldn't comment on personnel issues.
# Sentence 2: The main psychologist in the Rodriguez case, Dwight Close, referred questions to an agency spokeswoman, who didn't immediately return a call.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 195
# Sentence 1: Our goals is not to go out and start suing companies, McBride said.
# Sentence 2: As we go down the licensing path, our goal is not to start suing companies," McBride said.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 203
# Sentence 1: The driver of the truck escaped and is now being sought by the police, Supoyo said.
# Sentence 2: But police say the driver of the truck has not been found and is wanted for questioning.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 207
# Sentence 1: Klarman was arrested by FBI agents in the Hamptons, an exclusive summer resort enclave east of New York City.
# Sentence 2: Klarman was arrested by FBI agents Monday morning at his home in New York.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 209
# Sentence 1: Four versions of Windows operating systems are targeted: Windows NT, Windows 2000, Windows XP and Windows Server 2003.
# Sentence 2: The new worm affects these Windows systems: 2000, XP, NT 4.0 and Server 2003.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 210
# Sentence 1: It calls for the agency to plan an independent safety and engineering organization.
# Sentence 2: The agency has yet to fully formulate a strategy for the creation of an independent engineering technical authority.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 214
# Sentence 1: Results of the 2001 Aboriginal Peoples Survey released yesterday by Statistics Canada suggest living standards have improved but still lag for those off reserves.
# Sentence 2: The 2001 Aboriginal Peoples Survey released Wednesday by Statistics Canada says living standards have improved but still lag for the Inuit and those who leave their often impoverished reserves.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 222
# Sentence 1: Sen. John Kerry, Massachusetts Democrat, came in second place for the quarter with $5.8 million.
# Sentence 2: As expected, Dean led the field in the second quarter with $7.6 million raised.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 225
# Sentence 1: The Prime Minister, Junichiro Koizumi, joined the criticism.
# Sentence 2: Prime Minister Junichiro Koizumi said Mr Ota deserved to be criticised.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 227
# Sentence 1: Speaking for the first time since being charged with child molestation, Jackson added, "Why not?
# Sentence 2: Michael Jackson spoke out for the first time Sunday night since the latest accusations of child molestation.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 243
# Sentence 1: Her amendment would have changed the bill by keeping with current Texas law, which gives school districts the option to hold a moment of silence and recite the pledge.
# Sentence 2: The legislation would replace the current Texas law, which gives school districts the option of holding a period of silence and reciting the pledge.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 244
# Sentence 1: Talabani told him the Governing Council would "need UN assistance and advice in implementing the new decisions which have been taken."
# Sentence 2: Talabani told him Iraqi leaders would "need U.N. assistance and advice in implementing the new decisions which have been taken" on organising an interim Iraqi government by June.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 267
# Sentence 1: The Food and Drug Administration rejected ImClone's 2001 application to sell Erbitux, citing shoddy research.
# Sentence 2: The U.S. Food and Drug Administration rejected ImClone's original application in December 2001, saying the trial had been sloppily conducted.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 271
# Sentence 1: Its shares jumped to $54.50 in pre-open trading from $50.90 at Wednesday's close.
# Sentence 2: Shares jumped almost 7 percent in pre-open trading, rising to $18.26 from $17.05 at Tuesday's close.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 275
# Sentence 1: Five-time Tour de France winner and cancer survivor Lance Armstrong had a few words of advice for other cancer survivors in Denver on Friday.
# Sentence 2: Five-time Tour de France winner Lance Armstrong is in Denver today for a meeting about surviving cancer.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 284
# Sentence 1: But church members and observers say they expect that the decision could be problematic for many Episcopalians.
# Sentence 2: But church members and observers say they anticipate that the decision here could pose doctrinal problems for some Episcopalians who believe the Bible prohibits homosexuality.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 290
# Sentence 1: As planned, the services will be rolled into Yukon when it ships (see story).
# Sentence 2: The reporting services will also be rolled into Yukon as planned, sources said.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 306
# Sentence 1: But he said labor would see whether other senators can increase the value of awards proposed by Hatch and create a mechanism to ensure the fund remains solvent.
# Sentence 2: Democrats now hope to increase the value of awards proposed by Hatch and to create a mechanism to ensure the fund remains solvent.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 320
# Sentence 1: On Tuesday, the central bank left interest rates steady, as expected, but also declared that overall risks were weighted toward weakness and warned of deflation risks.
# Sentence 2: The central bank's policy board left rates steady for now, as widely expected, but surprised the market by declaring that overall risks were weighted toward weakness.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 322
# Sentence 1: They also found shortness was associated with a family history of hearing loss.
# Sentence 2: Shortness was found twice as often in those with hearing loss.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 336
# Sentence 1: Last year, he made an unsuccessful bid for the Democratic nomination for governor.
# Sentence 2: He ran last year for the Democratic nomination for Texas governor, but lost the primary to multimillionaire Tony Sanchez.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 338
# Sentence 1: The last time the S&P had a larger one-day point loss was also May 19, when it gave back 23.53 to close at 920.77.
# Sentence 2: The last time it had a larger one-day loss was July 1, 2002, when it shed 59.41 to close at 1,403.80.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 344
# Sentence 1: Part of the accord was the implementation of a special health council that would monitor health spending and progress in reforming the health system.
# Sentence 2: A key portion of the accord was the implementation of a special council to monitor health spending, set goals for the system and measure progress in reforming health care.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 349
# Sentence 1: Genentech Inc., the world's second-biggest biotechnology company, and Xoma Ltd. said their Rapitva drug failed to help patients with rheumatoid arthritis in a study.
# Sentence 2: Genentech Inc., the world's second-largest biotechnology company, and Xoma Ltd. said they will terminate Phase II testing of their Raptiva rheumatoid-arthritis drug after finding no benefit for patients.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 354
# Sentence 1: Shares ended Wednesday at $6.83, up 2 cents.
# Sentence 2: Shares of Goodyear rose 2 cents on Wednesday and closed at $6.83.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 356
# Sentence 1: Federal prosecutors, the Securities and Exchange Commission, and the mortgage company's regulator launched investigations into Freddie Mac's shake-up.
# Sentence 2: The Securities and Exchange Commission and the U.S. Attorney have opened investigations into Freddie Mac over its accounting practices.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 379
# Sentence 1: Ray Brent Marsh, 29, faces multiple counts of burial service fraud, making false statements, abuse of a dead body and theft.
# Sentence 2: Ray Brent Marsh, 29, also faces charges of abuse of a body, and theft.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 384
# Sentence 1: In April, it had forecast operating earnings in the range of 60 to 80 cents a share.
# Sentence 2: Kodak expects earnings of 5 cents to 25 cents a share in the quarter.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 385
# Sentence 1: Hampton Township is a few miles northeast of Bay City, about 100 miles away.
# Sentence 2: Hampton Township is located a few kilometers northeast of Bay City, near Michigan's Thumb.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 404
# Sentence 1: Although it's unclear whether Sobig was to blame, The New York Times also asked employees at its headquarters yesterday to shut down their computers because of "system difficulties."
# Sentence 2: The New York Times asked employees at its headquarters to shut down their computers yesterday because of "computing system difficulties."
# Predicted Label: 0
# True Label: 1
# ---
# Index: 413
# Sentence 1: He refused to reveal what percentage of flights carried sky marshals, or whether they would be increased.
# Sentence 2: He refused to say what percentage of domestic flights had security officers on board.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 415
# Sentence 1: The victim, whose name was not released, underwent surgery at the hospital.
# Sentence 2: The wounded doctor, whose name was withheld, underwent surgery at the hospital for three gunshot wounds.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 429
# Sentence 1: Federal and local officials, including Bush, saw no apparent sign of terrorism.
# Sentence 2: Federal officials earlier said there is no evidence of terrorism.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 436
# Sentence 1: Several current and former ferry officers have said the rules were routinely ignored and seldom enforced.
# Sentence 2: Some current and former ferry employees have said those rules were often ignored.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 465
# Sentence 1: Board Chancellor Robert Bennett declined to comment on personnel matters Tuesday.
# Sentence 2: Mr. Mills declined to comment yesterday, saying that he never discussed personnel matters.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 470
# Sentence 1: Bremer said one initiative is to launch a $70 million nationwide program in the next two weeks to clean up neighborhoods and build community projects.
# Sentence 2: Bremer said he would launch a $70-million program in the next two weeks to clean up neighborhoods across Iraq and build community projects, but gave no details.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 511
# Sentence 1: City-grown pollution, and ozone in particular, is tougher on country trees, says Cornell University ecologist Jillian Gregg.
# Sentence 2: I know this sounds counterintuitive, but it's true: City-grown pollution -- and ozone in particular -- is tougher on country trees, U.S. ecologist Jillian Gregg said.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 520
# Sentence 1: State government sources said Travis' move was a direct result of the controversy over the Boudin parole decision.
# Sentence 2: Sources say this decision was a direct result of the decision to release Boudin.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 521
# Sentence 1: The Nikkei average closed up 1.5 percent at 8,152.16, a one-month high.
# Sentence 2: The Nikkei average ended the morning up half a percent at 8,071.00.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 526
# Sentence 1: He failed a field sobriety test and a blood-alcohol test produced a reading of 0.18 -- well above Tennessee's level of presumed intoxication of 0.10, police said.
# Sentence 2: The player's eyes were bloodshot and a blood-alcohol test produced a reading of 0.18 - well above Tennessee's level of presumed intoxication of 0.10, the report said.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 536
# Sentence 1: The recent turnaround in the stock market and an easing in unemployment claims should keep consumer expectations at current levels and may signal more favorable economic times ahead.
# Sentence 2: The recent turnaround in the stock market and an easing in unemployment claims "may signal more favorable economic times ahead," she said.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 537
# Sentence 1: Early Wednesday, the benchmark 10-year US10YT=RR had lost 16/32 in price, driving its yield up to 3.33 percent from 3.26 percent late Tuesday.
# Sentence 2: Further out the curve, the benchmark 10-year note US10YT=RR shed 26/32 in price, taking its yield to 3.27 percent from 3.17 percent.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 547
# Sentence 1: The Passion will feature actor James Caviezel as Christ and actress Monica Bellucci as Mary Magdalene.
# Sentence 2: Directed by Gibson, the reported $25 million production stars Jim Caviezel as Jesus and Monica Bellucci as Mary Magdalene.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 553
# Sentence 1: The Dodgers won their sixth consecutive game their longest win streak since 2001 as they edged Colorado, 3-2, Wednesday in front of a crowd of 25,332 at Dodger Stadium.
# Sentence 2: The Dodgers won their sixth consecutive game and seventh in their last nine as they beat Colorado 3-2 on Wednesday in front of a crowd of 25,332 at Dodger Stadium.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 555
# Sentence 1: Mr Pollard said: "This is a terrible personal tragedy and a shocking blow for James's family.
# Sentence 2: Nick Pollard, the head of Sky News said: "This is a shocking blow for James's family.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 558
# Sentence 1: The technology-laced Nasdaq Composite Index was off 11.64 points, or 0.60 percent, at 1,912.65.
# Sentence 2: The technology-laced Nasdaq Composite Index (.IXIC: Quote, Profile, Research) ended off 2.96 points, or 0.15 percent, at 1,921.33.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 576
# Sentence 1: Fed policy-makers signaled they were prepared to cut rates, now at a 41-year low, to ward off even the threat of deflation.
# Sentence 2: Fed policy-makers last week signaled they are prepared to cut that rate to ward off even the threat of deflation.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 577
# Sentence 1: It appears that many employers accused of workplace discrimination will be considered guilty until they can prove themselves innocent, he said.
# Sentence 2: Employers accused of workplace discrimination now are considered guilty until they can prove themselves innocent.
# 1	3068989	3068932	The formula for its baby food is prepared by the German-owned Humana Milchunion.	The formula is produced for Remedia by German company Humana Milchunion.
# 1	2202632	2202780	Nearly one in 10 people have a gene mutation that can raise their risk of cancer by a quarter or more, U.S. researchers reported on Thursday.	Nearly one in 10 people have a gene mutation that can raise their risk of cancer by 25 percent or more, US researchers reported yesterday.
# 1	3046212	3046273	The findings are published in the November 6 edition of the journal Nature.	Both studies are published on Thursday in Nature, the British weekly science journal.
# 0	1559085	1559178	The man wasn't on the ice, but trapped in the rapids, swaying in an eddy about 250 feet from the shore.	The man was trapped about 250 feet from the shore, right at the edge of the falls.
# 0	1805630	1805435	Texas Instruments climbed $1.37 to $19.25 yesterday and Novellus Systems Inc. advanced $1.76 to $36.31.	Texas Instruments climbed $US1.37 to $US19.25 and Novellus Systems advanced $US1.76 to $US36.31, each having been raised to overweight" by Lehman.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 580
# Sentence 1: The economy, nonetheless, has yet to exhibit sustainable growth.	But the economy hasn't shown signs of sustainable growth.
# 0	2692086	2691868	Yee is a Chinese-American who converted to Islam after graduating from the U.S. Military Academy at West Point.	Yee is a 1990 graduate of the U.S. Military Academy at West Point, New York.
# 1	283697	283287	Meanwhile, students and others at Pacific Lutheran University near Tacoma, about 40 miles to the south, acted out a second, simultaneous attack on campus.	Meanwhile, volunteers at Pacific Lutheran University near Tacoma, about 40 miles to the south, simulated a second, simultaneous attack.
# 1	2521741	2521730	The suspect has been charged with juvenile delinquency, based on intentionally causing damage to computers.	A news release from the office said the arrest was for an act of juvenile delinquency based on intentionally causing damage to protected computers.
# 1	69795	69776	Cisco executives said they were encouraged by $1.3 billion in cash flow and the increase in net income, but hoped for a rebound.	Cisco executives were encouraged by $1.3 billion in cash flow and the increase in net income, but said they remained ``cautiously optimistic'' about a rebound.
# 1	2706235	2706274	Jail warden Gene Fischi said said Selenski and Bolton broke their 12-inch-by-18-inch cell window, threw a mattress to the ground and shimmied down the rope to a second-story roof.	Warden Gene Fischi said the two inmates broke a 12-by-18-inch cell window, threw a mattress to the ground, and clambered down the makeshift rope to a second-story roof.
# 0	267366	267390	Linda Saunders pleaded guilty in federal court to six charges, including extortion, money laundering and conspiracy.	Former Phipps aides Linda Saunders and Bobby McLamb have both pleaded guilty to federal charges including extortion.
# 1	1605338	1605488	Trans fats are created when hydrogen is added to vegetable oil, solidifying it and increasing the shelf life of certain food products.	Trans fats are created when vegetable oil has been partially hydrogenated, solidifying it and increasing the shelf life of certain products.
# 1	3042078	3042062	MEN who drink tea, particularly green tea, can greatly reduce their risk of prostate cancer, a landmark WA study has found.	DRINKING green tea can dramatically reduce the risk of men contracting prostate cancer, a study by Australian researchers has discovered.
# 1	2179041	2179199	Full classes of 48 each are booked through the end of next month, he said, and the agency plans to double its classes in January.	Full classes of 48 are booked through September, he said, and the Transportation Security Administration plans to double its classes in January.
# 0	1120715	1120672	Anything less is unacceptable, said Gordon, the ranking Democrat on the House Space and Aeronautics subcommittee.
# Sentence 2: Gordon is the senior Democrat on the House Subcommittee on Space and Aeronautics.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 581
# Sentence 1: Chief Justice William Rehnquist and Justices Antonin Scalia and Sandra Day O'Connor agreed with Thomas.
# Sentence 2: He was joined by Chief Justice William H. Rehnquist and Justices Sandra Day O'Connor and Antonin Scalia.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 592
# Sentence 1: He was tracked to Atlanta where he was arrested on Tuesday night.
# Sentence 2: He was arrested in Atlanta, Georgia, on Monday night by police acting on a tip-off.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 597
# Sentence 1: The mother also alleged in the lawsuit that she was sexually assaulted by one of the guards.
# Sentence 2: The mother also contended that she was sexually assaulted by one of the guards during the 1998 confrontation.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 601
# Sentence 1: The bank's shares fell 45 cents in trading yesterday to $91.51 per share.
# Sentence 2: Shares of M&T, which is based in Buffalo, fell 41 cents, to $91.51.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 610
# Sentence 1: It was better under Saddam," said 28-year-old Mushtaq Talib, a job-seeking army deserter, when asked what message he would like to convey to Powell.
# Sentence 2: It was better under Saddam...The war did nothing for us, said 28-year-old Mushtaq Talib, a job-seeking army deserter, when asked what message he would give to Powell.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 628
# Sentence 1: After that, college President Paul Pribbenow told him to wrap up his speech.
# Sentence 2: After Hedges' microphone was unplugged for a second time, Pribbenow told him to wrap up his speech.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 636
# Sentence 1: Russian stocks fell after the arrest last Saturday of Mikhail Khodorkovsky, chief executive of Yukos Oil, on charges of fraud and tax evasion.
# Sentence 2: The weekend arrest of Russia's richest man, Mikhail Khodorkovsky, chief executive of oil major YUKOS, on charges of fraud and tax evasion unnerved financial markets.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 639
# Sentence 1: We've become like total strangers, Klein quotes him as saying.
# Sentence 2: We've become like total strangers, John told a pal two days before his death.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 653
# Sentence 1: An injured woman co-worker also was hospitalized and was listed in good condition.
# Sentence 2: A woman was listed in good condition at Memorial's HealthPark campus, he said.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 668
# Sentence 1: Young has 28 days to file a response and ask the NASD for a hearing.
# Sentence 2: Under NASD regulations, Mr. Young can file a response and request a hearing before an NASD panel.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 670
# Sentence 1: Our strong preference is to achieve a financial restructuring out of court, and we remain hopeful we can do so, chief executive Marce Fuller said.
# Sentence 2: Our strong preference is to achieve a financial restructuring out of court, Mirant CEO Marce Fuller said in a prepared statement early Friday.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 673
# Sentence 1: The officials did not say whether U.S. forces crossed into Syrian territory and were vague about how the Syrian border guards became involved.
# Sentence 2: U.S. officials did not say whether American forces, who were acting on intelligence, crossed into Syrian territory and were vague about how the Syrian guards were involved.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 678
# Sentence 1: Apple Computer's new online music service sold more than 1 million songs during its first week of operation, the company said Monday.
# Sentence 2: Apple Computer Inc. said Monday it exceeded record industry expectations by selling more than 1 million songs since the launch of its online music store a week ago.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 682
# Sentence 1: Other countries and private creditors are owed at least $80 billion in addition.
# Sentence 2: Other countries are owed at least $US80 billion ($108.52 billion).
# Predicted Label: 1
# True Label: 0
# ---
# Index: 697
# Sentence 1: If we could do that throughout the world, we could end terrorism, he said.
# Sentence 2: This is a hospital that treats everybody as people, and if we could do that throughout the world, we could end terrorism."
# Predicted Label: 0
# True Label: 1
# ---
# Index: 703
# Sentence 1: I think he has to disembrace Putin and put him on notice that he is taking the country in the wrong direction," Soros said.
# Sentence 2: President Bush has to put Putin on notice that he is taking Russia in the wrong direction, Soros said.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 707
# Sentence 1: State police said as many as 30 workers were trapped immediately after the garage collapsed.
# Sentence 2: As many as 30 people were believed to be trapped inside initially, the state police said.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 712
# Sentence 1: OPEC producers at a meeting on Wednesday are set to pressure independent oil exporters to contribute to the cartel's next supply cut to allow for the return of Iraqi oil.
# Sentence 2: OPEC this week is set to pressure independent exporters to back the cartel's next supply cut to prevent the resumption of Iraqi exports undercutting oil prices.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 721
# Sentence 1: The broad Standard & Poor's 500 Index .SPX gained 22.25 points, or 2.23 percent, to 1,018.22, based on the latest available figures.
# Sentence 2: The broad Standard & Poor's 500 Index .SPX gained 11.22 points, or 1.13 percent, at 1,007.19.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 725
# Sentence 1: The House barely had the necessary 100 members present for a quorum.
# Sentence 2: A hundred House members are needed for a quorum.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 726
# Sentence 1: The Agriculture Department already has issued a recall for 10,410 pounds of beef slaughtered Dec. 9 at Vern's Moses Lake Meat Co. in Moses Lake, Wash.
# Sentence 2: The Agriculture Department already has issued a recall for beef slaughtered along with the infected cow Dec. 9 at a meat company in Moses Lake, Wash.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 739
# Sentence 1: He presented the map at last week's Sixth International Conference on Mars in Pasadena, Calif.
# Sentence 2: Feldman presented the most recent findings and the new map Friday at the sixth International Conference on Mars in Pasadena, Calif.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 744
# Sentence 1: The weather service reported maximum sustained winds of nearly 105 miles an hour with stronger gusts.
# Sentence 2: Maximum sustained winds were around 40 mph, with stronger gusts.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 746
# Sentence 1: The updated products include Pylon Pro, Pylon Conduit, Pylon Anywhere, and Pylon Application Server.
# Sentence 2: The new products on the desktop side include the latest versions of Pylon Conduit and Pylon Pro.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 747
# Sentence 1: Malvo, 18, will go on trial Nov. 10 for the fatal shooting of FBI analyst Linda Franklin outside a Home Depot store in Falls Church, Va.
# Sentence 2: Malvo, 18, is charged in the fatal shooting of FBI analyst Linda Franklin outside a Home Depot store in Falls Church.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 761
# Sentence 1: Michael W. Stout, 56, was named executive vice president and chief information officer.
# Sentence 2: The third appointment was to a new job, executive vice president and chief staff officer.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 768
# Sentence 1: And they ordered state troopers to prevent camera crews from filming Private Lynch outside her home.
# Sentence 2: They ordered state troopers to close the roads leading to her home after her motorcade passed, to prevent camera crews from pursuing her.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 791
# Sentence 1: Penn Traffic's stock closed at 36 cents per share on Wednesday on Nasdaq, up two cents.
# Sentence 2: Penn Traffic stock closed Wednesday at 36 cents, up 2 cents, or 6.2 percent, from Tuesday's close.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 794
# Sentence 1: Rusch has also allowed five or more earned runs in each of his last three starts.
# Sentence 2: Redman has allowed two earned runs or less in six of his nine starts.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 801
# Sentence 1: Others with such a status are Egypt, Israel, and Australia.
# Sentence 2: Nations like Israel and Australia already have such status.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 803
# Sentence 1: The Bush administration said Monday it will propose a rule change allowing governors to seek exemptions from a policy blocking road-building in remote areas of national forests.
# Sentence 2: The Bush administration wants to let governors seek exemptions from a ban on mining, drilling and logging in one-third of the national forests.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 805
# Sentence 1: After 10 years of debate, the government is requiring food labels to reveal exact levels of the artery clogger.
# Sentence 2: That's about to change, now that the government is requiring food labels to reveal exact levels of the artery clogger.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 811
# Sentence 1: Excluding the charges, analysts, on average, expected a loss of 11 cents a share.
# Sentence 2: Analysts polled by Thomson Financial First Call had been expected to see a loss of about 11 cents a share from continuing operations.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 820
# Sentence 1: Pollack said the plaintiffs failed to show that Merrill and Blodget directly caused their losses.
# Sentence 2: Basically, the plaintiffs did not show that omissions in Merrill's research caused the claimed losses.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 821
# Sentence 1: Prosecutors did an about-face in May and asked that the autopsy reports be unsealed after portions of Conner Peterson's autopsy report favorable to the defense were leaked to the media.
# Sentence 2: They asked that the autopsy reports be unsealed after portions of the autopsy report on Peterson's unborn son that were favorable to the defense were leaked to the media.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 822
# Sentence 1: In the latest top-level shuffle at CNN, Teya Ryan is leaving her post as general manager of U.S. programming, the network announced.
# Sentence 2: In CNN's latest move to rejuvenate ratings, the network has ousted Teya Ryan, general manager of U.S. programming.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 825
# Sentence 1: With diplomacy heating up in the nearly 10-month-old nuclear crisis, Chinese Foreign Minister Li Zhaoxing is slated to visit South Korea from August 13 to 15.
# Sentence 2: With diplomacy heating up in the nearly 10-month-old crisis, Chinese Foreign Minister Li Zhaoxing flies to Japan on Sunday en route to South Korea on August 13.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 826
# Sentence 1: So far, they have searched Pennsylvania, Ohio, Michigan, Illinois and Indiana, authorities in those state said.
# Sentence 2: So far, authorities also have searched areas in Pennsylvania, Ohio, Indiana, and Michigan.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 827
# Sentence 1: Besides battling its sales slump, Siebel also has been sparring with some investors upset about huge stock option windfalls company managers have pocketed.
# Sentence 2: Besides a sales slump, Siebel is sparring with some shareholders over management stock option windfalls.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 833
# Sentence 1: Five-year notes US5YT=RR rose 6/32 in price for a yield of 3.08 percent, down from 3.12 percent late on Tuesday.
# Sentence 2: Five-year notes US5YT=RR added 2/32 to give a yield of 3.10 percent from 3.12 percent.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 836
# Sentence 1: Lesser rewards of $15 million each were offered for the same information about his sons, Uday and Qusay.
# Sentence 2: Similar rewards were offered for his two sons and lieutenants, Uday and Qusay.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 846
# Sentence 1: Also in the majority were Chief Justice William H. Rehnquist and Justices John Paul Stevens, Sandra Day O'Connor, Ruth Bader Ginsburg and Stephen G. Breyer.
# Sentence 2: Chief Justice William H. Rehnquist and Justices John Paul Stevens, Sandra Day OConnor, Ruth Bader Ginsburg and Stephen Breyer agreed with Souter.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 857
# Sentence 1: Aventis, based in Strasbourg, France, is one of a handful of companies that still make the flu vaccine.
# Sentence 2: Aventis, based in Strasbourg, France, is one of the leading producers of the vaccine and one of a handful of companies that still make it.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 864
# Sentence 1: In two weeks, he'll probably send out Peace Rules in the Preakness.
# Sentence 2: Frankel said Peace Rules will run in the Preakness Stakes on May 17.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 872
# Sentence 1: Another big gainer was Rambus Inc. (nasdaq: RMBS - news - people), which shot 32 percent higher.
# Sentence 2: Rambus Inc. (nasdaq: RMBS - news - people) shot up 38 percent, making it the biggest percentage gainer on the Nasdaq.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 874
# Sentence 1: The impact of these shortages, U.S. Energy Secretary Spencer Abraham warned yesterday, "will touch virtually every American."
# Sentence 2: The U.S. administration cranked up concerns of impending natural gas shortages yesterday, a supply crunch that officials said "will touch virtually every American."
# Predicted Label: 1
# True Label: 0
# ---
# Index: 884
# Sentence 1: I never punished a victim,'' said Brigadier General Taco Gilbert, the school's former number two officer.
# Sentence 2: I never blamed a victim, I never punished a victim,'' said Brig. Gen. Taco Gilbert, the school's former No. 2 officer.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 921
# Sentence 1: Started on Christmas Day in 1931, the Met's matinee broadcasts have introduced opera to millions of people around the world.
# Sentence 2: Started on Christmas Day in 1931 with Humperdinck's "Hansel and Gretel," the Met matinee broadcasts have introduced opera to millions of people around the world.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 923
# Sentence 1: The boy also sprayed the room full of retardant from fire extinguishers, which made it hard to see, the chief said.
# Sentence 2: The boy fired once into a wall and sprayed the room with fire extinguishers, making it hard to see, the chief said.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 927
# Sentence 1: Campaign officials said the moves may have been a source of some friction with Fowler.
# Sentence 2: Aides to the general said Mr. Segal's arrival could have been the source of friction with Mr. Fowler.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 943
# Sentence 1: New Line Cinema's prequel comedy, "Dumb and Dumberer: When Harry Met Lloyd" opened with $11.1 million.
# Sentence 2: The idiot-buddy prequel Dumb And Dumberer: When Harry Met Lloyd debuted at No. 6, with $11.1 million.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 951
# Sentence 1: China's Health Ministry said five more people had died of Sars and a further 159 were infected.
# Sentence 2: On Monday, China said nine more people had died from SARS and that 160 more were infected with the virus.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 955
# Sentence 1: Russin did not comment; his lawyer did not attend the hearing and did not return phone messages.
# Sentence 2: His lawyer, a cousin, Basil Russin, did not attend the hearing and did not return phone messages.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 958
# Sentence 1: Several shots rang out in the darkness, but only one gator had been killed by 11 p.m.
# Sentence 2: Several shots rang out Wednesday night, but no gators were killed then.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 959
# Sentence 1: Sales of $21.6 billion, up 10 percent from $19.7 billion a year ago, were ahead of Wall Street's estimate of $21.4 billion.
# Sentence 2: Microsoft posted sales of $8.1 billion, up from $7.3 billion a year ago and ahead of analysts' estimates of $7.9 billion.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 973
# Sentence 1: Grassley and Baucus rejected any disparity in drug benefits.
# Sentence 2: Grassley and Baucus said they had rejected that approach in their plan.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 975
# Sentence 1: In fact, I was physically sick several times at this stage, because he looked so desperate, she said.
# Sentence 2: Speaking about the day before he was found dead, she said: "I was physically sick several times at this stage because he looked so desperate.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 983
# Sentence 1: Police believe Wilson shot Reynolds, then her mother once in the head before fatally turning the gun on herself.
# Sentence 2: Police believe Wilson then shot Jennie Mae Robinson once in the head before turning the gun on herself.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 992
# Sentence 1: The body of one of the four teens, 17-year-old Max Guarino, was found April 25 in Long Island Sound.
# Sentence 2: Max Guarino, 17, was found April 25 in the water off City Island.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1002
# Sentence 1: According to security sources, London Metropolitan Police Commissioner John Stevens placed his force on its highest state of alert last week following the warning.
# Sentence 2: The Telegraph can reveal that Sir John Stevens, the Metropolitan Police Commissioner, placed his force on its highest alert last week.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1012
# Sentence 1: These days, even death penalty proponents in the Legislature say they are solidly outnumbered by opponents.
# Sentence 2: These days, death-penalty backers in the legislature acknowledge that they are outnumbered.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1014
# Sentence 1: The biggest cut ordered was for Hanover Lloyds Insurance Co. -- 31 percent.
# Sentence 2: The department ordered Hanover Insurance to cut its rates by 31 percent.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1020
# Sentence 1: Prosecutors maintained that Durst murdered Black to try to assume Black's identity.
# Sentence 2: Prosecutors called Durst a cold-blooded killer who shot Black to steal his identity.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1035
# Sentence 1: It is priced at $5,995 for an unlimited number of users tapping into the single processor, or $195 per user with a minimum of five users.
# Sentence 2: It is priced at $5,995 or $195 on a per user licensing plan with a minimum of five users.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1046
# Sentence 1: But HRT should not be used to prevent heart disease or any other chronic condition.
# Sentence 2: The clear message is it should not be used to prevent cardiovascular disease, Manson said.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1054
# Sentence 1: Voters in Cleveland Heights, Ohio, approved a proposal allowing same-sex couples - and also unmarried heterosexual couples - to officially register as domestic partners.
# Sentence 2: Voters in Cleveland Heights, Ohio, were asked to decide whether to allow same-sex couples - and also unmarried heterosexual couples - to officially register as domestic partners.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1058
# Sentence 1: But they don’t realize that until it’s too late (of course) because they’re potential victims in a horror movie.
# Sentence 2: But they don't realize that until it's too late (of course) because they're potential victims.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1061
# Sentence 1: The third case involved contracts signed by Sierra Pacific Resources SRP.N utility Nevada Power Co. and two municipal utilities.
# Sentence 2: A separate case seeking to renegotiate contracts was filed by Sierra Pacific Resources SRP.N utility Nevada Power Co. and two municipal utilities.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1074
# Sentence 1: The UMass president has acknowledged talking to him once since he went on the lam in 1995, just before federal indictments were handed down.
# Sentence 2: The UMass president, who testified before a congressional committee last week, has acknowledged talking to him once since he went on the lam in 1995.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1086
# Sentence 1: The Justice Department and the Federal Communications Commission have the final say.
# Sentence 2: But the deal must get approval from the Federal Communications Commission and the Justice Department's antitrust division.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1089
# Sentence 1: Hidalgo County Judge Ramon Garcia remembers how he and his friends used to have to sneak around the school yard to speak Spanish.
# Sentence 2: Hidalgo County Judge Ramon Garcia says when he was growing up, he wasn't allowed to speak Spanish at school.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1090
# Sentence 1: Hovan did not speak, but his lawyer, John Speranza, said his client "did not wake up that day" intending to hurt anyone.
# Sentence 2: Hovan "did not wake up that day" intending to hurt anyone, defense attorney John Speranza said.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1096
# Sentence 1: National Breast Cancer Centre chief executive Professor Christine Ewan said it was too early to quantify the risk to women.
# Sentence 2: National Breast Cancer Centre head Professor Christine Ewan said there was no need for panic.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1099
# Sentence 1: The highest-paid Washington private-college president is Susan Resneck Pierce, who heads the University of Puget Sound.
# Sentence 2: The highest-paid private-college president in Washington is University of Puget Sound President Susan Resneck Pierce at $314,160, the Chronicle said.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1106
# Sentence 1: Pollack said yesterday the plaintiffs failed to show that Merrill and Blodget directly caused their losses.
# Sentence 2: Basically, the plaintiffs did not show that omissions in Merrill's research caused the claimed losses.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1112
# Sentence 1: They were tossed around like feathers, Gordon said.
# Sentence 2: The concrete barriers (between lanes) were being tossed around like feathers.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1114
# Sentence 1: On May 1, he crawled through a narrow, winding canyon, rappelled down a 60-foot cliff and walked some six miles down the canyon.
# ...
# Sentence 2: Stanford (46-15) plays South Carolina (44-20) on Friday in the opening game of the double-elimination tournament.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1204
# Sentence 1: AirTran officials and a Boeing official declined to comment yesterday.
# Sentence 2: Trish York, a spokeswoman for Boeing, declined to comment on the deal.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1232
# Sentence 1: British Airways' New York-to-London runs will end in October.
# Sentence 2: British Airways plans to retire its seven Concordes at the end of October.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1253
# Sentence 1: After the Houston event, Bush returned to his Crawford, Texas, ranch, where he will host Italian Prime Minister Silvio Berlusconi on Sunday and Monday.
# Sentence 2: Bush is spending the weekend at his Crawford ranch, where he will play host to Italian Prime Minister Silvio Berlusconi.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1262
# Sentence 1: He has been at UCSD since 1991 and was appointed chancellor in 1996, after spending 22 years with AT&T Bell Labs, where he worked on superconductors and other materials.
# Sentence 2: Dynes has been at UC San Diego since 1991 after spending 22 years with AT&T Bell Labs, where he worked on superconductors and other materials.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1263
# Sentence 1: The stock rose $2.11, or about 11 percent, to close on Friday at $21.51 on the New York Stock Exchange.
# Sentence 2: PG&E Corp. shares jumped $1.63 or 8 percent to $21.03 on the New York Stock Exchange on Friday.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1268
# Sentence 1: The commission estimates California lost $1.34 billion -- the most of any state -- to tax shelters in 2001.
# Sentence 2: The commission estimated California lost $937 million to corporate tax shelters in 2001.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1276
# Sentence 1: The new companies will begin trading on Nasdaq today under the ticker symbols PLMO and PSRC.
# Sentence 2: Also as part of the deal, PalmSource stock will begin trading on the NASDAQ stock market Wednesday under the ticker symbol: PSRC.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1277
# Sentence 1: There's a Jeep in my parents' yard right now that's not theirs,'' said Perry, whose parents are vacationing in North Carolina.
# Sentence 2: There's a Jeep in my parents' yard right now that's not theirs, she said.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1289
# Sentence 1: Of 24 million phoned-in votes, 50.28 percent were for Studdard, putting him 130,000 votes ahead of Aiken.
# Sentence 2: Of the 24 million phone votes cast, Studdard was only 130,000 votes ahead of Aiken.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1291
# Sentence 1: Hispanics, the fastest growing ethnic group in the US, have overtaken blacks to become the largest minority in the US, according to newly released government figures.
# Sentence 2: Hispanics have officially overtaken African Americans as the largest minority group in the US, according to a report released by the US Census Bureau.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1297
# Sentence 1: As a result of the decision, Brown said CareFirst subscribers won't have access to Blue Cross Blue Shield nationwide and to international service providers.
# Sentence 2: But if the trademark is withdrawn, subscribers won't have access to Blue Cross Blue Shield nationwide and international service providers.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1304
# Sentence 1: The poll shows Bill White supported by 53 percent of surveyed voters -- Orlando Sanchez by 35 percent.
# Sentence 2: The latest 11 News/Houston Chronicle Poll shows White supported by 53 percent of surveyed voters, far ahead of Orlando Sanchez's 35 percent.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1327
# Sentence 1: If convicted of the spying charges, he could face the death penalty.
# Sentence 2: The charges of espionage and aiding the enemy can carry the death penalty.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1331
# Sentence 1: Dennehy, who transferred to Baylor last year after getting kicked off the University of New Mexico Lobos for temper tantrums, had begun to read the Bible daily.
# Sentence 2: Dennehy, who transferred to Baylor last year after getting kicked off the University of New Mexico Lobos for temper tantrums, became a born-again Christian in June 2002.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1333
# Sentence 1: Complicating the situation is the presence of battle-hardened Liberians who have been fighting on both sides.
# Sentence 2: Fighting has continued sporadically in the west, where it is complicated by the presence of battle-hardened Liberians on both sides.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1351
# Sentence 1: Selenski descended down the wall and used the mattress to climb over razor wire.
# Sentence 2: Selenski used the mattress to scale a 10-foot razor wire, Fischi said.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1353
# Sentence 1: Canadian officials have agreed to run a complementary threat response exercise.
# Sentence 2: Canadian officials will participate through a command post exercise.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1356
# Sentence 1: Oracle followed with 33.8 percent of the market and Microsoft came in third with an 18 percent share.
# Sentence 2: IBM ranked second with 24 percent share there, and Microsoft ranked third.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1359
# Sentence 1: In addition, primary care trusts (PCTs) were given star ratings for the first time this year.
# Sentence 2: Primary Care Trusts and Mental Health Trusts have also been formally rated for the first time this year.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1360
# Sentence 1: Kodak expects earnings of 5 cents to 25 cents a share in the quarter.
# Sentence 2: Analysts surveyed by Thomson First Call had expected Kodak to earn 68 cents a share for the quarter.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1365
# Sentence 1: Opponents of the ban also are planning a protest rally at City Hall tomorrow at 1 p.m. to coincide with the scheduled start of the state ban.
# Sentence 2: In New York City, opponents of the ban are planning a protest rally at City Hall Thursday at 1 p.m.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1372
# Sentence 1: Police using pepper spray arrested 12 people Monday night at a march and rally by about 400 activists protesting an annual training seminar of the Law Enforcement Intelligence Unit.
# Sentence 2: Police used pepper spray and rubber bullets to disperse a downtown march and rally last night by activists protesting an annual police intelligence-training seminar.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1381
# Sentence 1: A Chinese court yesterday jailed two people for life and imprisoned 12 others for organising a sex party involving hundreds of Japanese tourists.
# Sentence 2: A court in southern China yesterday jailed two people for life for organising a three-day sexual romp with hundreds of prostitutes by visiting employees of a Japanese company.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1389
# Sentence 1: I had no direct interest and Craxi begged me to intervene because he believed the operation damaged the state, he told a packed courtroom during a 45-minute address.
# Sentence 2: I had no direct interest, and Craxi begged me to intervene because he believed that the operation damaged the state, Mr. Berlusconi said.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1391
# Sentence 1: Such a step could put the issue before the UN Security Council.
# Sentence 2: The matter could then be sent to the U.N. Security Council.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1395
# Sentence 1: The department ordered an 18.2 percent reduction for Allstate Texas Lloyds and a 12 percent reduction for State Farm Lloyds.
# Sentence 2: The department ordered a 12 percent reduction for State Farm Lloyds, the state's largest insurer, and an 18.2 percent reduction for Allstate Texas Lloyds, the third-largest.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1400
# Sentence 1: The European Union is basically absent, said Tito Barbini, regional minister for agriculture in Tuscany, Italy.
# Sentence 2: Tito Barbini, a regional minister for agriculture in Tuscany, Italy, criticized the absence Tuesday in Sacramento.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1412
# Sentence 1: A Global Crossing spokeswoman and a Pentagon spokesman declined to comment.
# Sentence 2: A Global Crossing representative had no immediate comment.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1424
# Sentence 1: Dewhurst's proposal calls for an abrupt end to the controversial "Robin Hood" plan for school finance.
# Sentence 2: The committee would propose a replacement for the "Robin Hood" school finance system.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1425
# Sentence 1: Dynes came to UC San Diego in 1991 after 22 years as a physicist with AT&T Bell Labs.
# Sentence 2: Dynes has been at UC San Diego since 1991 after spending 22 years with AT&T Bell Labs, where he worked on superconductors and other materials.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1429
# Sentence 1: The military said it had killed 12 rebels and captured nine in the campaign so far, for the loss of six soldiers wounded.
# Sentence 2: The military said it had killed 16 rebels and captured nine in the campaign so far, with one soldier killed and six wounded.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1433
# Sentence 1: The court case does not include another rule, which also took effect Nov. 29, that allows cell customers to keep their phone numbers when they switch wireless companies.
# Sentence 2: The court case does not involve another rule that that allows cell customers to keep their phone numbers when they switch wireless companies.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1453
# Sentence 1: Air Canada, the largest airline in Canada and No. 11 in the world, has been under court protection from creditors since April 1.
# Sentence 2: The No. 11 airline in the world, Air Canada has been under court protection from creditors since April 1.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1471
# Sentence 1: The dollar fell as low as $1.1624 per euro from $1.1486 on Friday, and traded at $1.1594 at 10:15 a.m. in London.
# Sentence 2: The dollar dropped to $1.1564 per euro at 7:30 a.m. in London from $1.1486 on Friday.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1476
# Sentence 1: The first health-care worker in the country to die of SARS was a Filipina-Canadian who contracted the disease at North York General Hospital, the site of the second outbreak.
# Sentence 2: Emile Laroza, 51, contracted SARS while working as a nurse at North York General Hospital, the epicentre of the second SARS outbreak.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1492
# Sentence 1: NBC will probably end the season as the second most popular network behind CBS, although it's first among the key 18-to-49-year-old demographic.
# Sentence 2: NBC will probably end the season as the second most-popular network behind CBS, which is first among the key 18-to-49-year-old demographic.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1493
# Sentence 1: Happy Family has ex-Night Court star Larroquette and Christine Baranski as a couple whose children move back home after college.
# Sentence 2: Happy Family has ex-Night Court star Larroquette and Christine Baranski as a couple with grown children who won't leave their lives.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1510
# Sentence 1: Shiites make up 20 percent of the country's population.
# Sentence 2: Sunnis make up 77 percent of Pakistan's population, Shiites 20 percent.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1511
# Sentence 1: Dotson told FBI agents that he shot Dennehy after the player tried to shoot him, according to the arrest warrant affidavit.
# Sentence 2: Dotson was arrested July 21 after telling FBI agents he shot Dennehy when Dennehy tried to shoot him, according to the arrest warrant affidavit.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1518
# Sentence 1: Google's investors include prominent VC firms Kleiner Perkins Caufield & Byers and Sequoia Capital, the paper noted.
# Sentence 2: Google's early stage backers in include California-based Stanford University and VC firms Kleiner Perkins and Sequoia Capital.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1521
# Sentence 1: It seemed like an isolated incident," said Ariel Dean of Washington D.C., who earned a degree in political science.
# Sentence 2: It seemed like an isolated incident,'' said graduate Ariel Dean of Washington, D.C.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1524
# Sentence 1: A new study, conducted in Europe, found the medicine worked just as well as an earlier disputed study, sponsored by ImClone Systems, said it did.
# Sentence 2: Doctors concluded Erbitux, the cancer drug that enmeshed ImClone Systems in an insider trading scandal, worked just as well as an earlier company-sponsored study said it did.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1536
# Sentence 1: An incremental step reported by researchers at the University of California, San Francisco, is the latest in a decade-long effort.
# Sentence 2: The incremental step, reported by researchers at UC San Francisco, is the latest in a decade-long effort to infect mice with the virus.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1553
# Sentence 1: Veteran stage and screen actor Hume Cronyn died of cancer Sunday.
# Sentence 2: Character actor Hume Cronyn, 91, died Sunday at his home in Connecticut.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1566
# Sentence 1: Yee is a 1990 graduate of the U.S. Military Academy at West Point, New York.
# Sentence 2: Yee grew up in the United States and graduated from the U.S. Military Academy at West Point.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1568
# Sentence 1: Kroger Co., which owns Ralphs, and Albertsons Inc. bargain jointly with Safeway and locked out their union workers the next day.
# Sentence 2: In a show of corporate solidarity, Kroger Co., which owns Ralphs, and Albertson Inc. locked out their workers the next morning.
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1575
# Sentence 1: Brendsel and chief financial officer Vaughn Clarke resigned June 9.
# Sentence 2: The company's chief executive retired and chief financial officer resigned.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1580
# Sentence 1: The village last said sorry in 1993, when it presented the Methodist Church of Fiji with Baker's boots - which cannibals had tried unsuccessfully to cook and eat.
# Sentence 2: In 1993, villagers presented the Methodist Church of Fiji with Baker's boots — which cannibals tried unsuccessfully to cook and eat.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1584
# Sentence 1: Smith, 59, is charged with fraud for allegedly filing false reports to FBI headquarters about Leung's reliability and with gross negligence for allegedly allowing her access to classified materials.
# Sentence 2: Smith, 59, is charged with filing false reports to FBI headquarters about Leung's reliability and allowing her access to classified materials.
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1608
# Sentence 1: Bush turned out a statement yesterday thanking the commission for its work, and said, "Our journey into space will go on."
# Sentence 2: Mr. Bush did not discuss this when he issued a brief statement yesterday thanking the commission for its work, and saying, "Our journey into space will go on."
# Predicted Label: 1
# True Label: 0
# ---
# Index: 1610
# Sentence 1: I would rather be talking about positive numbers than negative.	But I would rather be talking about high standards rather than low standards.
# Sentence 2: nan
# Predicted Label: 0
# True Label: 1
# ---
# Index: 1614
# Sentence 1: Several states and the federal government later passed similar or more strict bans.
# Sentence 2: Following California's lead, several states and the federal government passed similar or tougher bans.
# Predicted Label: 1
# True Label: 0
# ---
